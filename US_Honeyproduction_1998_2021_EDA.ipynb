# %%
#@title Importing Dataset and Libraries

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("honeyproduction 1998-2021.csv")
df = pd.DataFrame(df)

# %%
#@title Checking for Null Value

df.isna().sum()

# %% [markdown]
# **As there is no null value in the dataset, we can directly start the analysis part.**

# %%
#@title 1. How has honey production yield changed from 1998 to 2021?

year_wise_prod = df.groupby(by='year')['totalprod'].sum()
print(year_wise_prod.sort_values(ascending=False)[:1]) #printing the heighest value

year_wise_prod.plot(marker='.', color= 'purple')

plt.xlabel('year')
plt.ylabel('production in Pounds')
plt.title('Honey production from 1998 to 2021', fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# **Insights ▶**
#
#   - In the year 2000, the honey production is highest of all time
#   - As we can see from graph, Honey production is decreasing overtime.

# %%
#@title Unique values in the column
df.State.nunique()

# %%
#@title 2. Over time, what are the major production trends across the states?

state_wise_max_prod = df.groupby(by='State')['totalprod'].sum()

state_wise_max_prod.sort_values(ascending=False) 
state_wise_max_prod.plot(kind='barh', figsize= [10,12], color = "magenta")
plt.grid(axis='x')
plt.title("Major Production Trend Citywise", color='blue', fontsize=15)
plt.xlabel("Total production in all time", weight='bold', fontsize=10)
plt.ylabel("State", weight='bold',fontsize=10)
plt.show()

# %%
#@title Top 10 Cities productionwise
state_wise_max_prod.sort_values(ascending=False)[:10]

# %% [markdown]
# ## Year wise production in states :
# (Top 10 states are selected production wise)

# %%
#@title Year 1998 production

year_1998_prod = df[['State', 'totalprod']].loc[df.year == 1998]
year_1998_prod = year_1998_prod.set_index('State')
y_1998 = year_1998_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar',color='red', title='Year_1998', ylabel='Totalprod in lb')

plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2000 production
year_2000_prod = df[['State', 'totalprod']].loc[df.year == 2000]
year_2000_prod = year_2000_prod.set_index('State')
y_2000 = year_2000_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar', title='Year_2000', ylabel='Totalprod in lb')

plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2002 production

year_2002_prod = df[['State', 'totalprod']].loc[df.year == 2002]
year_2002_prod = year_2002_prod.set_index('State')
y_2002 = year_2002_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar', color='pink', title='Year_2002', ylabel='Totalprod in lb')

plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2004 production

year_2004_prod = df[['State', 'totalprod']].loc[df.year == 2004]
year_2004_prod = year_2004_prod.set_index('State')
y_2004 = year_2004_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar',color="purple",title='Year_2004', ylabel='Totalprod in lb')


plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2006 production
year_2006_prod = df[['State', 'totalprod']].loc[df.year == 2006]
year_2006_prod = year_2006_prod.set_index('State')
y_2006 = year_2006_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar',color="green",title='Year_2006', ylabel='Totalprod in lb')

plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2008 production
year_2008_prod = df[['State', 'totalprod']].loc[df.year == 2008]
year_2008_prod = year_2008_prod.set_index('State')
y_2008 = year_2008_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar',title='Year_2008', ylabel='Totalprod in lb')

plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2010 production
year_2010_prod = df[['State', 'totalprod']].loc[df.year == 2010]
year_2010_prod = year_2010_prod.set_index('State')
y_2010 = year_2010_prod.sort_values(by='totalprod',ascending=False)[:10].plot(kind='bar',color='green', title='Year_2010', ylabel='Totalprod in lb')

plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2012 production
year_2012_prod = df[['State', 'totalprod']].loc[df.year == 2012]
year_2012_prod = year_2012_prod.set_index('State')
y_2012 = year_2012_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar',color="orange", title='Year_2012', ylabel='Totalprod in lb')

plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2014 production
year_2014_prod = df[['State', 'totalprod']].loc[df.year == 2014]
year_2014_prod = year_2014_prod.set_index('State')
y_2014 = year_2014_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar',color='skyblue', title='Year_2014', ylabel='Totalprod in lb')


plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2016 production
year_2016_prod = df[['State', 'totalprod']].loc[df.year == 2016]
year_2016_prod = year_2016_prod.set_index('State')
y_2016 = year_2016_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar', title='Year_2016', ylabel='Totalprod in lb')

plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2018 production
year_2018_prod = df[['State', 'totalprod']].loc[df.year == 2018]
year_2018_prod = year_2018_prod.set_index('State')
y_2018 = year_2018_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar', title='Year_2018',color='gray', ylabel='Totalprod in lb')


plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2020 production
year_2020_prod = df[['State', 'totalprod']].loc[df.year == 2020]
year_2020_prod = year_2020_prod.set_index('State')
y_2020 = year_2020_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar',color='magenta',title='Year_2020', ylabel='Totalprod in lb')


plt.xticks(rotation = 45)
plt.show()

# %%
#@title Year 2021 production
year_2021_prod = df[['State', 'totalprod']].loc[df.year == 2021]
year_2021_prod = year_2021_prod.set_index('State')
year_2021_prod.sort_values(by='totalprod', ascending=False)[:10].plot(kind='bar', title='Year_2021', ylabel='Totalprod in lb')

plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Insights ▶**
#
# - North Dakota has heighest production in all years
# - In the year 1998, California was the heighest production city but from 1999 North Dakota is the highest honey producing state.

# %% [markdown]
# ## 3. Does the data show any trends in terms of the number of honey producing colonies and yield per colony before 2006,which was when concern over Colony Collapse Disorder spread nationwide?

# %%
before_2006 = df.loc[df.year<2006]

fig, ax1 = plt.subplots(figsize=[8,5])
 
ln1 = ax1.plot(before_2006.groupby(by='year')['numcol'].sum(), color='magenta',marker='.', label='Number of honey producing colonies')
ax1.xaxis.grid()
ax1.yaxis.grid()

ax2 = ax1.twinx()
ln2 = ax2.plot(before_2006.groupby(by='year')['yieldpercol'].sum(), color='red', marker='.', label='Honey yield per colony')

# getting all the labels
lines = ln1+ln2
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels)

plt.title("Honey production trend before 2006", color='blue')
ax1.set_xlabel("Year", weight='bold')
ax1.set_ylabel("Number of honey production colony",labelpad= 10,weight='bold')
ax2.set_ylabel("Honey yield per colony in lb",rotation=-90, labelpad=20, weight='bold')

plt.show()

# %% [markdown]
# **Insights ▶**
#
# - We can see that from the graph, before the year 2006 number of honey producing colonies are decreasing in number year by year.
# - As the number of colonies are decreasing, so the honey producing is also decreasing year by year.
# - Though it seems that the last point for Number of honey producing colonies and honey yield per colony merged with each other but they have completely different values.

# %%
#@title After 2006

after_2006 = df.loc[df.year>2006]

fig, ax1 = plt.subplots(figsize=[8,5])
 
ln1 = ax1.plot(after_2006.groupby(by='year')['numcol'].sum(), color='magenta',marker='.', label='Number of honey producing colonies')
ax1.xaxis.grid()
ax1.yaxis.grid()

ax2 = ax1.twinx()
ln2 = ax2.plot(after_2006.groupby(by='year')['yieldpercol'].sum(), color='red', marker='.', label='Honey yield per colony')

# getting all the labels
lines = ln1+ln2
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels)

plt.title("Honey production trend after 2006", color='blue')
ax1.set_xlabel("Year", weight='bold')
ax1.set_ylabel("Number of honey production colony",labelpad= 10,weight='bold')
ax2.set_ylabel("Honey yield per colony in lb",rotation=-90, labelpad=20, weight='bold')

plt.show()

# %% [markdown]
# ##4. Are there any patterns that can be observed between total honey production and value of production every year?

# %%
year_wise_totalprod = df.groupby(by='year')['totalprod'].sum()
year_wise_prodvalue = df.groupby(by ='year')['prodvalue'].sum()

fig, ax3 = plt.subplots(figsize=[8,5])

ln1 = ax3.plot(year_wise_totalprod.index, year_wise_totalprod.values,marker='.', label ="Year wise total production")
ax3.set_ylim((1.1*pow(10,8)), (4*pow(10,8)))

ax4 = ax3.twinx()

ln2 = ax4.plot(year_wise_prodvalue.index, year_wise_prodvalue.values , color='red',marker='.', label= "Year wise production value")
ax4.set_ylim((1.1*pow(10,8)), (4*pow(10,8)))

ax3.xaxis.grid()
ax3.yaxis.grid()

lines = ln1 + ln2
labels = [l.get_label() for l in lines]
ax3.legend(lines, labels, loc='upper left')


plt.title("Total Production vs Value of Production", color='blue')
ax3.set_xlabel("Year", weight='bold')
ax3.set_ylabel("Year wise total production",labelpad= 10,weight='bold')
ax4.set_ylabel("Year wise production value",rotation=-90, labelpad=20, weight='bold')
plt.show()

# %% [markdown]
# **Insights ▶**
# - In the chart we can see, the total honey production per year goes down i.e. the honey production is decreasing.
# - As the production is decreasing, the value of production is increasing year by year.
# - Heighest value of production comes in the year 2014 and the lowest is in 1999.

# %% [markdown]
# ##5. How has the value of production, which in some sense could be tied to demand, changed every year?

# %%
plt.plot(year_wise_prodvalue.index, year_wise_prodvalue.values , color='red')

plt.title("Value of Production (1998 - 2021)")
plt.xlabel("Year")
plt.ylabel("Dollars")
plt.grid()
plt.show()

# %% [markdown]
# **Insights ▶**
# - We can state from the graph that the demand is increasing year by year and as the production is not upto mark so the price is increasing year by year.
